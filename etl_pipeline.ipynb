# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "http://books.toscrape.com/index.html"
url2="http://books.toscrape.com/catalogue/page-2.html"
url3="http://books.toscrape.com/catalogue/page-3.html"
response = requests.get(url)
html = response.content
scraped = BeautifulSoup(html, 'html.parser')

# %%
title_text = scraped.title.text.strip()
print(title_text)
# Out:
# All products | Books to Scrape - Sandbox

# %%
table_data=[]
articles = scraped.select(".product_pod")
for article in articles:
    title = article.h3.a["title"]
    price = article.find("p", class_="price_color")
    availibility=article.find("p",class_="instock availability").get_text().strip()
    image=article.img["src"]
    price_float = float(price.text.lstrip("£"))
    currency=price.string[0]
    data_item={"title":title,"price":price_float,"currency":currency,"availibility":availibility,"book_cover":image}
    table_data.append(data_item)

# %%
df = pd.DataFrame(table_data)
df.head(10)
# Out:
#                                                title  price currency  \
# 0                     Slow States of Collapse: Poems  57.31        £
# 1                              Reasons to Stay Alive  26.41        £
# 2                        Private Paris (Private #10)  47.61        £
# 3  #HigherSelfie: Wake Up Your Life. Free Your So...  23.11        £
# 4                    Without Borders (Wanderlove #1)  45.07        £
# 5                                   When We Collided  31.77        £
# 6                       We Love You, Charlie Freeman  50.27        £
# 7            Untitled Collection: Sabbath Poems 2014  14.27        £
# 8  Unseen City: The Majesty of Pigeons, the Discr...  44.18        £
# 9                                     Unicorn Tracks  18.78        £
#
#   availibility                                         book_cover
# 0     In stock  ../media/cache/72/41/72417db983862010ef0c1a25d...
# 1     In stock  ../media/cache/cb/bd/cbbdb0222ee8a0f6ab6165741...
# 2     In stock  ../media/cache/9d/05/9d0533bae1578846d728a8291...
# 3     In stock  ../media/cache/9c/46/9c463c7631c82401160fd3b55...
# 4     In stock  ../media/cache/24/e2/24e2f5c9d325c4004d8190c05...
# 5     In stock  ../media/cache/08/04/08044269fc197645268a6197c...
# 6     In stock  ../media/cache/5f/15/5f152afdbc42356ecba02f610...
# 7     In stock  ../media/cache/f9/3b/f93b4a650f03a5d21f2436d78...
# 8     In stock  ../media/cache/41/a2/41a20f35adf0caea24f208dc0...
# 9     In stock  ../media/cache/76/8e/768ea5924ac1ef6297c2be995...

# %%
#Save df in csv format
df.to_csv (r'C:\Users\ingen\OneDrive\Bureau\retviews\Books.csv', index = False, header=True)

# %%
#Save df in excel format
df.to_excel ('Books1.xlsx',index=True)

# %%
#Add id column
df = df.reset_index()
df = df.rename(columns={"index":"book_id"})

# %%
df
# Out:
#     book_id                                              title  price  \
# 0         0                     Slow States of Collapse: Poems  57.31
# 1         1                              Reasons to Stay Alive  26.41
# 2         2                        Private Paris (Private #10)  47.61
# 3         3  #HigherSelfie: Wake Up Your Life. Free Your So...  23.11
# 4         4                    Without Borders (Wanderlove #1)  45.07
# 5         5                                   When We Collided  31.77
# 6         6                       We Love You, Charlie Freeman  50.27
# 7         7            Untitled Collection: Sabbath Poems 2014  14.27
# 8         8  Unseen City: The Majesty of Pigeons, the Discr...  44.18
# 9         9                                     Unicorn Tracks  18.78
# 10       10  Unbound: How Eight Technologies Made Us Human,...  25.52
# 11       11  Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRo...  16.28
# 12       12  Throwing Rocks at the Google Bus: How Growth B...  31.12
# 13       13                                    This One Summer  19.49
# 14       14                                             Thirst  17.27
# 15       15        The Torch Is Passed: A Harding Family Story  19.09
# 16       16                    The Secret of Dreadwillow Carse  56.13
# 17       17  The Pioneer Woman Cooks: Dinnertime: Comfort C...  56.41
# 18       18                                The Past Never Ends  56.50
# 19       19  The Natural History of Us (The Fine Art of Pre...  45.22
#
#    currency availibility                                         book_cover
# 0         £     In stock  ../media/cache/72/41/72417db983862010ef0c1a25d...
# 1         £     In stock  ../media/cache/cb/bd/cbbdb0222ee8a0f6ab6165741...
# 2         £     In stock  ../media/cache/9d/05/9d0533bae1578846d728a8291...
# 3         £     In stock  ../media/cache/9c/46/9c463c7631c82401160fd3b55...
# 4         £     In stock  ../media/cache/24/e2/24e2f5c9d325c4004d8190c05...
# 5         £     In stock  ../media/cache/08/04/08044269fc197645268a6197c...
# 6         £     In stock  ../media/cache/5f/15/5f152afdbc42356ecba02f610...
# 7         £     In stock  ../media/cache/f9/3b/f93b4a650f03a5d21f2436d78...
# 8         £     In stock  ../media/cache/41/a2/41a20f35adf0caea24f208dc0...
# 9         £     In stock  ../media/cache/76/8e/768ea5924ac1ef6297c2be995...
# 10        £     In stock  ../media/cache/4a/3b/4a3b055f9e378a95fedbef55e...
# 11        £     In stock  ../media/cache/36/df/36df4caaf1420b1183a823535...
# 12        £     In stock  ../media/cache/03/86/038650c9e7517b4baf2a423cd...
# 13        £     In stock  ../media/cache/c4/dd/c4ddd9ced89966b0602ec85e0...
# 14        £     In stock  ../media/cache/c4/0a/c40a64f59e7487b1a80a049f6...
# 15        £     In stock  ../media/cache/33/e5/33e507172541628acfd421503...
# 16        £     In stock  ../media/cache/c4/a2/c4a2a1a026c67bcceb5a411c7...
# 17        £     In stock  ../media/cache/b7/f4/b7f4843dbe062d44be1ffcfa1...
# 18        £     In stock  ../media/cache/89/b8/89b850edb01851a91f64ba114...
# 19        £     In stock  ../media/cache/5d/7f/5d7f496cdf5e5962a73ecdcc1...

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
# Defining our connection variables
username = "root"
password = "" 
ipaddress = "localhost"
port = 3306
dbname = "retviews" 
mysql_str = f'mysql+pymysql://{username}:{password}@{ipaddress}:{port}/{dbname}'
cnx = create_engine(mysql_str)
max_id=pd.read_sql('SELECT max(book_id) as ID FROM book', cnx).values
print(max_id.item())
if (max_id.item()):
    df["book_id"]=df["book_id"]+max_id.item()+1
# Out:
# None

# %%
df.to_sql("book", con=cnx, index=False, if_exists="append")
